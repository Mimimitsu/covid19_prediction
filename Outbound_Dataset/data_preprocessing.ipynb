# %%
import pandas as pd
import os

# %%
path = "D:/Data/Mylecture/DATA7901/Outbound_Dataset/OUTBOUND_DATA_1995-2019"
dirs = os.listdir(path)
df_list = []
origin_list = []

for file in dirs:
    # 处理数据
    df = pd.read_excel(path + '/' + file)
    df = df[6:]
    df.columns = ['Destination', 'SERIES', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '% Change 2019-2018']
    #将介绍信息清理后, 发现末尾仍有两行多余信息, 将其清除
    df.dropna(axis=0, subset=['SERIES'], inplace=True)
    df_list.append(df)

    origin_name = (str(file).split(' '))[0]
    # print((str(file).split(' '))[0])
    origin_list.append(origin_name)

# %%
df_test = df_list[1]
df_test
# Out:
#                           Destination SERIES    1995    1996    1997    1998  \
# 6                              Angola    TFR     NaN     NaN     NaN     NaN
# 7                 Antigua and Barbuda    TFR     NaN     NaN     NaN     NaN
# 8                             Armenia    TFR     1.0     NaN    15.0    46.0
# 9                           Australia    VFR     NaN     NaN    90.0    94.0
# 10                         Azerbaijan    VFR     NaN     NaN     NaN     NaN
# ..                                ...    ...     ...     ...     ...     ...
# 88                            Ukraine    TFR  1374.0    13.0   707.0   108.0
# 89               United Arab Emirates   THSN     NaN     NaN     NaN     NaN
# 90           United States of America    TFR     NaN  3326.0  1786.0  2017.0
# 91                         Uzbekistan    VFR     NaN     NaN     NaN     NaN
# 92  Venezuela, Bolivarian Republic of    TFN     NaN     NaN     NaN     NaN
#
# ...

# %%
df_test.drop(columns=['1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '% Change 2019-2018'], inplace=True)
df_test.reset_index(inplace=True, drop=True)
df_test
# Out:
#                           Destination SERIES     2018     2019
# 0                              Angola    TFR     26.0     10.0
# 1                 Antigua and Barbuda    TFR      8.0      NaN
# 2                             Armenia    TFR    147.0      NaN
# 3                           Australia    VFR    380.0      NaN
# 4                          Azerbaijan    VFR    239.0    269.0
# ..                                ...    ...      ...      ...
# 82                            Ukraine    TFR   1654.0      NaN
# 83               United Arab Emirates   THSN   1728.0   4940.0
# 84           United States of America    TFR  17782.0  18715.0
# 85                         Uzbekistan    VFR     27.0      NaN
# 86  Venezuela, Bolivarian Republic of    TFN      NaN      NaN
#
# [87 rows x 4 columns]

# %%
df_test['2018'].fillna(value=0, inplace=True)
df_test['2019'].fillna(value=0, inplace=True)
df_test
# Out:
#                           Destination SERIES     2018     2019
# 0                              Angola    TFR     26.0     10.0
# 1                 Antigua and Barbuda    TFR      8.0      0.0
# 2                             Armenia    TFR    147.0      0.0
# 3                           Australia    VFR    380.0      0.0
# 4                          Azerbaijan    VFR    239.0    269.0
# ..                                ...    ...      ...      ...
# 82                            Ukraine    TFR   1654.0      0.0
# 83               United Arab Emirates   THSN   1728.0   4940.0
# 84           United States of America    TFR  17782.0  18715.0
# 85                         Uzbekistan    VFR     27.0      0.0
# 86  Venezuela, Bolivarian Republic of    TFN      0.0      0.0
#
# [87 rows x 4 columns]

# %%
Average = (df_test['2018'] + df_test['2019']) / 2
df_test['Average'] = Average

# %%
df_test
# Out:
#                           Destination SERIES     2018     2019  Average
# 0                              Angola    TFR     26.0     10.0     18.0
# 1                 Antigua and Barbuda    TFR      8.0      0.0      4.0
# 2                             Armenia    TFR    147.0      0.0     73.5
# 3                           Australia    VFR    380.0      0.0    190.0
# 4                          Azerbaijan    VFR    239.0    269.0    254.0
# ..                                ...    ...      ...      ...      ...
# 82                            Ukraine    TFR   1654.0      0.0    827.0
# 83               United Arab Emirates   THSN   1728.0   4940.0   3334.0
# 84           United States of America    TFR  17782.0  18715.0  18248.5
# 85                         Uzbekistan    VFR     27.0      0.0     13.5
# 86  Venezuela, Bolivarian Republic of    TFN      0.0      0.0      0.0
#
# [87 rows x 5 columns]

# %%
df_test.to_csv(path_or_buf="D:/Data/Mylecture/DATA7901/Outbound_Dataset/cleaning_dataset/" + "test" + ".csv", index=False)
